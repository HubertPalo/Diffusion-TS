# %%
from IPython.display import Image
Image(filename='D_UCI_trained_with_class_4_for_120000_epochs_tsne_freq.png')

# %%
from IPython.display import Image
Image(filename='D_UCI/10/D_UCI-trained_on-class_4-minmax_scaled-60000_epochs_tsne_freq.png')

# %%
from IPython.display import Image
Image(filename='D_UCI/10/D_UCI-trained_on-all_classes-minmax_scaled-480000_epochs_tsne_embedding.png')
